# %%
import pandas as pd
import statsmodels.formula.api as smf

facebook = pd.read_csv('DATA/dataset_Facebook.csv', delimiter=";")

# %%
import numpy as np 
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
facebook.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 19 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Page total likes                                                     500 non-null    int64
#  1   Type                                                                 500 non-null    object
#  2   Category                                                             500 non-null    int64
#  3   Post Month                                                           500 non-null    int64
#  4   Post Weekday                                                         500 non-null    int64
#  5   Post Hour                                                            500 non-null    int64
#  6   Paid                                                                 499 non-null    float64
# ...

# %%
facebook.describe()
# Out:
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        500.000000  500.000000  500.000000    500.000000  500.000000
# mean      123194.176000    1.880000    7.038000      4.150000    7.840000
# std        16272.813214    0.852675    3.307936      2.030701    4.368589
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       112676.000000    1.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136393.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  499.000000                  500.00000                     5.000000e+02
# mean     0.278557                13903.36000                     2.958595e+04
# ...

# %%
facebook.columns
# Out:
# Index(['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions'],
#       dtype='object')

# %% [markdown]
# Graphs for presentations

# %% [markdown]
# Line Plot

# %%
ax = sns.lineplot(x = 'Post Hour', y = 'Total Interactions', data = facebook, ci = False)

# %%
Bar Graph

# %%
bestday = sns.barplot(x = 'Post Weekday', y = 'Lifetime Post Total Reach', data = facebook, palette = ["red", "orange", "yellow", "green", "blue", "purple", "brown"], ci = False)

# %% [markdown]
# Other exploring graphs stuff

# %%
sns.pairplot(facebook[['comment','like','share','Total Interactions']], plot_kws = {"color": "purple"}, height = 10)

# %%
# orient = 'h' switches orientation to horizontal
# color = 'green' to change colors 
# https://htmlcolorcodes.com/color-picker/ and choose the color you want with the hex code #560FE5
# size stting function below

sns.set_style('ticks')
ax = sns.barplot(x = 'Total Interactions', y = 'like', color = '#560FE5', data = facebook, orient = 'h', ci = False)
# you can make it more appropriate by replacing (color = '#560FE5') with (palette = ["red", "green", "blue"])

# %%
# Note the marker designator, play with it, see what fits
ax =sns.scatterplot(x = 'Total Interactions' , y = 'Post Hour', data = facebook, color = 'green', marker = "p")

# %%
# Note the marker designator, play with it, see what fits
ax =sns.scatterplot(x = 'Post Hour' , y = 'Total Interactions', data = facebook, color = 'blue', marker = "p")

# %%
# seaborn calls this a distribution plot aka distplot
# great for investigating the distribution of a variable

# first create array containing data from dataframe

x = facebook['Total Interactions'].values
sns.distplot(x)

# %%
mean = facebook['Total Interactions'].mean()
sns.distplot(x)

# plt.axvline(mean, distance from x axis, length of line, color = 'red')
# we choose 1 as length of line because it's max value of a histogram 

plt.axvline(mean,0, 1, color = 'red')

# %%
x = facebook['Post Hour'].values
sns.distplot(x)

# %%
mean = facebook['Post Hour'].mean()
sns.distplot(x)
plt.axvline(mean,0, 1, color = 'red')

# %%
ax = sns.lineplot(x = 'Post Hour', y = 'Total Interactions', data = facebook, ci = False)

# %%
ax = sns.barplot(x = 'Post Hour', y = 'Total Interactions', data = facebook, palette = ["yellow", "blue"], ci = False)

# %%
sns.set_style('ticks')
ax = sns.barplot(x = 'Post Hour', y = 'Total Interactions', color = '#560FE5', data = facebook, orient = 'h', ci = False)
